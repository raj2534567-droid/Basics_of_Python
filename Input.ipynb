# %% [markdown]
# # Input : Taking Input From User

# %%
# input is a way of taking data from users
# input() statements is use to accept values from users
# input alwasy takes values as a string

a=input('Your Name')
print(a)
# Out:
# Your Name Rajeshwari
# Rajeshwari

# %%
# Practice question:

# Write a program to input 2 numbers % print their sum

a =int(input("enter the number"))
b =int(input("enter the number"))

print("The sum of a and B: ", a+b)
# Out:
# enter the number 6
# enter the number 4
# The sum of a and B:  10

# %%
# Write a program to input of square & print its area

side = int(input('side of the square:'))
area = side*side

print('Area of the square:' , area)
# Out:
# side of the square: 4
# Area of the square: 16

# %%
###### Write a program to input 2 floating point numbers and print thier numbers

a = float(input('Enter the First Number'))
b = float(input('Enter the Second Number'))

c = (a+b)/2

print('The avaerage of the floating number:' , c)
# Out:
# Enter the First Number 4.5
# Enter the Second Number 5.5
# The avaerage of the floating number: 5.0

# %%
# Write a program to input 2 int numbers a and b
# Print True if a is greater than or equls to b
# if not print false

a = float(input('Enter the First Number'))
b = float(input('Enter the Second Number'))

c = a >= b

print('A is greater than b:',c)
print('so this is printing true')
# Out:
# Enter the First Number 6.5
# Enter the Second Number 5.4
# A is greater than b: True
# so this is printing true
