# %% [markdown]
# # Variables

# %%
#  A Variable is name given to a memory location in aprogram
# Variable is basically a lable not a place

Variable = 'Value'

# Example:

name='Rajeshwari'
age=24
price=26.88

# And we can also print the variable's data by putting variable in print():

print(name)
print(age)
print(price)
# Out:
# Rajeshwari
# 24
# 26.88

# %%
# variables can also be pronounce by indentifiers
# Rules for identifiers
# Uppercase, Lowercase, digits or underscore(-)
# Variable can not be strat with digits
# Cannot use symbols like ! # $ % etc
# we can not use the reserved key words

# %%
# Comments 
# single line comments : "#"
# multiline comments : """ """

# We write or add comments to our code for sticky note.
# To explain the Codes.
# To temperory disable the code 
# to provide metadata

# %%
# Assining the same value to multiple variables

a = b = c = 10

print(a,b,c)
# Out:
# 10 10 10

# %%
# Assining multiple variables with multiple data at the same time(Parallel assigment)

a,b,c = 12, 15, 20

print(a,b,c)
# Out:
# 12 15 20

# %%
# Standard assining variables

a = "Raji"

print(a)
# Out:
# Raji
